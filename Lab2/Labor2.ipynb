# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*y
desolve(eqd,y)
# Out:
# _C*e^(2*x)

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol.substitute(_C==1)
# Out:
# e^(2*x)

# %%
soll=sol.substitute(_C==1)
plot(soll,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*y*x
desolve(eqd,y)
# Out:
# _C*e^(x^2)

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol.substitute(_C==1)
soll=sol.substitute(_C==1)
plot(soll,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==y/x
desolve(eqd,y)
# Out:
# _C*x

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol.substitute(_C==1)
soll=sol.substitute(_C==1)
plot(soll,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==(-2*x*y^2)/(x^2-1)
desolve(eqd,y)
# Out:
# 1/2/y(x) == _C + 1/2*log(x + 1) + 1/2*log(x - 1)

# %%
x=var('x')
y=function('y')(x)
eqd=(x^2-1)*diff(y,x)+2*x*y^2==0
sol=desolve(eqd,y)
yy=var('yy')
sol.substitute(y(x)==yy)
_C=var('_C')
f(x,yy,_C)=sol.substitute(y(x)==yy)
f(x,yy,_C)
implicit_plot(f(x,yy,0),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)+y*tan(x)==1/cos(x)
desolve(eqd,y)
# Out:
# (_C + tan(x))/sec(x)

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)+y*tan(x)==1/cos(x)
desolve(eqd,y)
soll=sol.substitute(_C==1)
plot(soll,x,-2,2)
# Out:
# verbose 0 (3839: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 200 points.
# verbose 0 (3839: plot.py, generate_plot_points) Last error message: 'unable to simplify to float approximation'
# Graphics object consisting of 0 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)+y*tan(x)==1/cos(x)
sol=desolve(eqd,y)
yy=var('yy')
sol.substitute(y(x)==yy)
_C=var('_C')
f(x,yy,_C)=sol.substitute(y(x)==yy)
f(x,yy,_C)
implicit_plot(f(x,yy,0),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)+(2/x)*y==x^3
desolve(eqd,y)
# Out:
# 1/6*(x^6 + 6*_C)/x^2

# %%
soll=sol.substitute(_C==1)
plot(soll,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)+(2/x)*y==x^3
sol=desolve(eqd,y)
soll=sol.substitute(_C==1)
plot(soll,x,5,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# Out:
# _C*e^(2*x)

# %%
#Aufgabe 2
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1+y^2
sol=desolve(eqd,y,ics=[0,1])
yy=var('yy')
sol.substitute(y(x)==yy)
_C=var('_C')
f(x,yy,_C)=sol.substitute(y(x)==yy)
f(x,yy,_C)
implicit_plot(f(x,yy,0),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1+y^2
sol=desolve(eqd,y,ics=[0,1])
sol
# Out:
# arctan(y(x)) == 1/4*pi + x

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)-2*y==-x^2
sol=desolve(eqd,y,ics=[0,1/4])
sol
# Out:
# 1/2*x^2 + 1/2*x + 1/4

# %%
soll=sol.substitute(_C==1)
plot(soll,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)+y*tan(x)==1/cos(x)
sol=desolve(eqd,y,ics=[0,0])
sol
# Out:
# tan(x)/sec(x)

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)+y*tan(x)==1/cos(x)
sol=desolve(eqd,y,ics=[0,0])
soll=sol.substitute(_C==1)
plot(soll,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#Aufgabe 3
#a
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)+(k/x)*y==x^3
sol=desolve(eqd,[y,x])
sol
# Out:
# (x^4*x^k/(k + 4) + _C)/x^k

# %%
#b
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)+(k/x)*y==x^3
sol=desolve(eqd,[y,x])
soll=sol.substitute(_C==1,k==1)
plot(soll,x,-5,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#c
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)+(k/x)*y==x^3
sol=desolve(eqd,[y,x],ics=[1,0])
soll=sol.substitute(_C==1,k==1)
plot(soll,x,-5,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#d
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)+(k/x)*y==x^3
sol=desolve(eqd,[y,x],ics=[1,0])
plot([sol(x,5),sol(x,6),sol(x,7)],x,5,10)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)+(k/x)*y==x^3
sol(x,k)=desolve(eqd,[y,x],ics=[1,0])
plot([sol(x,5),sol(x,6),sol(x,7)],x,5,10)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Aufgabe 4
#a
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)-(1/2)*y==cos(x)
sol=desolve(eqd,[y,x])
sol
# Out:
# -1/5*(2*(cos(x) - 2*sin(x))*e^(-1/2*x) - 5*_C)*e^(1/2*x)

# %%
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)-(1/2)*y==cos(x)
sol=desolve(eqd,[y,x])
_C=var('_C')
soll=sol.substitute(_C==1)
plot(soll,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#b
x,a=var('x,a')
y=function('y')(x)
eqd=diff(y,x)-(1/2)*y==cos(x)
sol=desolve(eqd,[y,x],ics=[0,a])
_C=var('_C')
sol
#ja, fur a=-2/5
# Out:
# 1/5*(5*a + 2)*e^(1/2*x) - 2/5*cos(x) + 4/5*sin(x)

# %%
#c
x,a=var('x,a')
y=function('y')(x)
eqd=diff(y,x)-(1/2)*y==cos(x)
sol(x,a)=desolve(eqd,[y,x],ics=[0,a])
_C=var('_C')
soll=sol.substitute(_C==1)
plot(soll(x,-1),x,-5,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,a=var('x,a')
y=function('y')(x)
eqd=diff(y,x)-(1/2)*y==cos(x)
sol(x,a)=desolve(eqd,[y,x],ics=[0,a])
_C=var('_C')
soll=sol.substitute(_C==1)
plot(soll(x,-(2/5)),x,-5,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,a=var('x,a')
y=function('y')(x)
eqd=diff(y,x)-(1/2)*y==cos(x)
sol(x,a)=desolve(eqd,[y,x],ics=[0,a])
_C=var('_C')
soll=sol.substitute(_C==1)
plot([soll(x,-2),soll(x,-(2/5)),sol(x,2)],x,-5,3)
# Out:
# Graphics object consisting of 3 graphics primitives
