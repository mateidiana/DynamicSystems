# %%
#Aufgabe 1
#a
t=var("t")
x=function("x")(t)
y=function("y")(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
desolve_system(syst,[x,y])
# Out:
# [x(t) == 1/2*(x(0) + 2*y(0))*e^(3*t) + 1/2*(x(0) - 2*y(0))*e^(-t),
#  y(t) == 1/4*(x(0) + 2*y(0))*e^(3*t) - 1/4*(x(0) - 2*y(0))*e^(-t)]

# %%
C1,C2=var('C1,C2')
desolve_system(syst,[x,y],[0,C1,C2])
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %%
sol=desolve_system(syst,[x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t)

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)

# %%
plot(sol_x(t,1,1),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t,1,1),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#b
t=var("t")
x=function("x")(t)
y=function("y")(t)
deq1=diff(x,t)==2*x-y
deq2=diff(y,t)==x+2*y
syst=[deq1,deq2]
desolve_system(syst,[x,y])
C1,C2=var('C1,C2')
desolve_system(syst,[x,y],[0,C1,C2])
sol=desolve_system(syst,[x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> (C1*cos(t) - C2*sin(t))*e^(2*t)

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> (C2*cos(t) + C1*sin(t))*e^(2*t)

# %%
plot(sol_x(t,1,1),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t,1,1),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#c
t=var("t")
x=function("x")(t)
y=function("y")(t)
z=function("z")(t)
deq1=diff(x,t)==x-y+z
deq2=diff(y,t)==x+y-z
deq3=diff(z,t)==-y+2*z
syst=[deq1,deq2,deq3]
desolve_system(syst,[x,y,z])
C1,C2,C3=var('C1,C2,C3')
desolve_system(syst,[x,y,z],[0,C1,C2,C3])
sol=desolve_system(syst,[x,y,z],[0,C1,C2,C3])
sol_x(t,C1,C2,C3)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t

# %%
sol_y(t,C1,C2,C3)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t + C2*e^t

# %%
sol_z(t,C1,C2,C3)=sol[2].rhs()
sol_z
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t

# %%
plot(sol_x(t,1,1,1),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t,1,1,1),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_z(t,1,1,1),t,-4,4,color='yellow')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#d
t=var("t")
x=function("x")(t)
y=function("y")(t)
deq1=diff(x,t)==5*x+3*y+1
deq2=diff(y,t)==-6*x-4*y+e^-t
syst=[deq1,deq2]
desolve_system(syst,[x,y])
C1,C2=var('C1,C2')
desolve_system(syst,[x,y],[0,C1,C2])
sol=desolve_system(syst,[x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3

# %%
plot(sol_x(t,1,1,1),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t,1,1,1),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#Aufgabe 2
#a
t=var("t")
x=function("x")(t)
y=function("y")(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,1,2]
sol=desolve_system(syst,vars,in_cond)
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> 5/2*e^(3*t) - 3/2*e^(-t)

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 5/4*e^(3*t) + 3/4*e^(-t)

# %%
plot(sol_x(t),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#b
t=var("t")
x=function("x")(t)
y=function("y")(t)
deq1=diff(x,t)==x-y+t-1
deq2=diff(y,t)==-2*x+4*y+cos(t)
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]
sol=desolve_system(syst,vars,in_cond)
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2

# %%
plot(sol_x(t),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#c
t=var("t")
x=function("x")(t)
y=function("y")(t)
deq1=diff(x,t)==x+2*y+e^-t
deq2=diff(y,t)==-2*x+y+1
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]
sol=desolve_system(syst,vars,in_cond)
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5

# %%
plot(sol_x(t),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#Aufgabe 3
#a
t=var("t")
x=function("x")(t)
y=function("y")(t)
deq1=diff(x,t)==y
deq2=diff(y,t)==-x-2*y
syst=[deq1,deq2]
C1,C2=var('C1,C2')
desolve_system(syst,[x,y],[0,C1,C2])
sol=desolve_system(syst,[x,y],[0,C1,C2])
sol
# Out:
# [x(t) == C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t),
#  y(t) == -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)]

# %%
#b
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t)

# %%
limit(sol_x,t=infinity)
# Out:
# t |--> 0

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)

# %%
limit(sol_y,t=infinity)
# Out:
# t |--> 0

# %%
#c
f1(x,y)=y
f2(x,y)=-x-2*y
plot_vector_field( [f1(x,y),f2(x,y)], [x,-10,10], [y,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#Aufgabe 4
#a
n=sqrt(f1(x,y)^2+f2(x,y)^2)
f1(x,y)=2*x+y
f2(x,y)=x+2*y
plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-100,100], [y,-100,100] )
#nu e 0 limita
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#b
n=sqrt(f1(x,y)^2+f2(x,y)^2)
f1(x,y)=y
f2(x,y)=-x
plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-10,10], [y,-10,10] )
#limita nu exista
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#c
n=sqrt(f1(x,y)^2+f2(x,y)^2)
f1(x,y)=-x-y
f2(x,y)=x-y
plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-10,10], [y,-10,10] )
#limita e 0
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#d
n=sqrt(f1(x,y)^2+f2(x,y)^2)
f1(x,y)=-2*x
f2(x,y)=-4*x-2*y
plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-10,10], [y,-10,10] )
#limita e 0
# Out:
# Graphics object consisting of 1 graphics primitive
