# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)+y==sin(x)+cos(x)
desolve(eqd,y)
# Out:
# _K2*cos(x) - 1/2*(x - 1)*cos(x) + _K1*sin(x) + 1/2*x*sin(x)

# %%
sol=desolve(eqd,y)
sol
# Out:
# _K2*cos(x) - 1/2*(x - 1)*cos(x) + _K1*sin(x) + 1/2*x*sin(x)

# %%
_K1,_K2=var('_K1,_K2')
sol.substitue(_K1==1,_K2==2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-6c702dbc3581> in <module>
#       1 _K1,_K2=var('_K1,_K2')
# ----> 2 sol.substitue(_K1==Integer(1),_K2==Integer(2))
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:4709)()
#     491             AttributeError: 'LeftZeroSemigroup_with_category.element_class' object has no attribute 'blah_blah'
#     492         """
# --> 493         return self.getattr_from_category(name)
#     494
#     495     cdef getattr_from_category(self, name):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.getattr_from_category (build/cythonized/sage/structure/element.c:4821)()
#     504         else:
# ...

# %%
_K1,_K2=var('_K1,_K2')
sol.substitute(_K1==1,_K2==2)
# Out:
# -1/2*(x - 1)*cos(x) + 1/2*x*sin(x) + 2*cos(x) + sin(x)

# %%
soll=sol.substitute(_K1==1,_K2==2)
plot(soll,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-y==e^(2*x)
desolve(eqd,y)
# Out:
# _K2*e^(-x) + _K1*e^x + 1/3*e^(2*x)

# %%
sol=desolve(eqd,y)
sol
# Out:
# _K2*e^(-x) + _K1*e^x + 1/3*e^(2*x)

# %%
_K1,_K2=var('_K1,_K2')
sol.substitute(_K1==1,_K2==2)
# Out:
# 1/3*e^(2*x) + 2*e^(-x) + e^x

# %%
soll=sol.substitute(_K1==1,_K2==2)
plot(soll,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)+4*y==1/cos(2*x)
desolve(eqd,y)
# Out:
# _K2*cos(2*x) + 1/4*cos(2*x)*log(cos(2*x)) + _K1*sin(2*x) + 1/2*x*sin(2*x)

# %%
sol=desolve(eqd,y)
sol
# Out:
# _K2*cos(2*x) + 1/4*cos(2*x)*log(cos(2*x)) + _K1*sin(2*x) + 1/2*x*sin(2*x)

# %%
_K1,_K2=var('_K1,_K2')
sol.substitute(_K1==1,_K2==2)
# Out:
# 1/4*cos(2*x)*log(cos(2*x)) + 1/2*x*sin(2*x) + 2*cos(2*x) + sin(2*x)

# %%
soll=sol.substitute(_K1==1,_K2==2)
plot(soll,x,-2,2)
# Out:
# verbose 0 (3839: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 122 points.
# verbose 0 (3839: plot.py, generate_plot_points) Last error message: 'can't convert complex to float'
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-diff(y,x)==1/(1+e^x)
desolve(eqd,y)
# Out:
# _K1*e^x + e^x*log((e^x + 1)*e^(-x)) + _K2 - x + log(e^x + 1)

# %%
sol=desolve(eqd,y)
sol
# Out:
# _K1*e^x + e^x*log((e^x + 1)*e^(-x)) + _K2 - x + log(e^x + 1)

# %%
_K1,_K2=var('_K1,_K2')
sol.substitute(_K1==1,_K2==2)
# Out:
# e^x*log((e^x + 1)*e^(-x)) - x + e^x + log(e^x + 1) + 2

# %%
soll=sol.substitute(_K1==1,_K2==2)
plot(soll,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-5*diff(y,x)+4*y==0
desolve(eqd,y,ics=[0,5,8])
# Out:
# e^(4*x) + 4*e^x

# %%
sol=desolve(eqd,y,ics=[0,5,8])
plot(sol,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
a=var('a')
y=function('y')(x)
eqd=diff(y,x,2)-diff(y,x)-2*y==0
desolve(eqd,y,ics=[0,a,2])
# Out:
# 1/3*(a + 2)*e^(2*x) + 2/3*(a - 1)*e^(-x)

# %%
sol=desolve(eqd,y,ics=[0,1,1])
plot(sol,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-4*diff(y,x)+5*y==2*x^2*e^x
desolve(eqd,y,ics=[0,2,3])
# Out:
# (cos(x) - 2*sin(x))*e^(2*x) + (x^2 + 2*x + 1)*e^x

# %%
sol=desolve(eqd,y,ics=[0,2,3])
plot(sol,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)+4*y==4*(sin(2*x)+cos(2*x))
desolve(eqd,y,ics=[pi,2*pi,2*pi])
# Out:
# 1/2*(6*pi - 1)*cos(2*x) - 1/2*(2*x - 1)*cos(2*x) + x*sin(2*x) + 1/2*sin(2*x)

# %%
sol=desolve(eqd,y,ics=[pi,2*pi,2*pi])
plot(sol,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive
